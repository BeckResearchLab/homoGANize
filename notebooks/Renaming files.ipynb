# %%
import glob
import os
import pandas as pd
from natsort import natsorted

# %%
path = 'C:\Users\ellie\Desktop\Dave Beck\Downloads\PaDEL-Descriptor\zinc 1'
files = os.listdir(path)

for index, file in enumerate(files):
    os.rename(os.path.join(path, file), os.path.join(path, str(index)+'.jpg'))

# %%
os.chdir(r'C:\Users\ellie\Desktop\Dave Beck\big datasets\csv')

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

zinc_descriptors = pd.concat([pd.read_csv(f) for f in all_filenames ])
zinc_descriptors.to_csv('zinc_descriptors.csv', index=False)
#export to csv
#combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
combined_zinc1.drop_duplicates(inplace=True, keep='first')

# %%
combined_zinc1.shape
# Out:
# (52194, 1445)

# %%
combined_zinc2.drop_duplicates(inplace=True, keep='first')
combined_zinc2.shape
# Out:
# (40226, 1445)

# %%
combined_zinc3.drop_duplicates(inplace=True, keep='first')
combined_zinc3.shape
# Out:
# (22744, 1445)

# %%
combined_zinc4.drop_duplicates(inplace=True, keep='first')
combined_zinc4.shape
# Out:
# (5000, 1445)

# %%
listed = [combined_zinc1,combined_zinc2,combined_zinc3, combined_zinc4]

# %%
combined_zinc1.to_csv('combined_zinc1.csv', index=False)

# %%
combined_zinc2.to_csv('combined_zinc2.csv', index=False)

# %%
combined_zinc3.to_csv('combined_zinc3.csv', index=False)

# %%
combined_zinc4.to_csv('combined_zinc4.csv', index=False)

# %%
combined_zinc1 = pd.read_csv('../../big datasets/csv/combined_zinc1.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-615fe99cc2ac> in <module>()
# ----> 1 combined_zinc1 = pd.read_csv('../../big datasets/csv/combined_zinc1.csv', index='Name')
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
combined_zinc1.set_index('Name')
# Out:
#                            nAcid   ALogP    ALogp2       AMR       apol  \
# Name
# AUTOGEN_zinc_smiles_1        NaN -0.0588  0.003457   59.2490  30.329137
# AUTOGEN_zinc_smiles_2        NaN  0.5471  0.299318   86.6026  42.807895
# AUTOGEN_zinc_smiles_3        0.0 -1.2694  1.611376   74.6158  39.727895
# AUTOGEN_zinc_smiles_4        NaN -1.2694  1.611376   74.6158  39.727895
# AUTOGEN_zinc_smiles_5        0.0  0.8833  0.780219   65.8004  36.252688
# AUTOGEN_zinc_smiles_6        NaN -2.4549  6.026534   75.7435  44.470274
# AUTOGEN_zinc_smiles_7        0.0  0.2350  0.055225   95.0888  53.111825
# AUTOGEN_zinc_smiles_8        0.0 -1.5289  2.337535   89.0826  49.500239
# AUTOGEN_zinc_smiles_9        0.0 -0.1931  0.037288   68.9788  42.013446
# AUTOGEN_zinc_smiles_10       0.0  0.0430  0.001849   64.0520  33.663102
# AUTOGEN_zinc_smiles_11       0.0 -0.1026  0.010527   87.0599  43.301930
# AUTOGEN_zinc_smiles_12       0.0 -0.2378  0.056549   45.7210  23.715551
# ...

# %%
combined_zinc1 = combined_zinc1.loc[~combined_zinc1.index.duplicated(keep='first')]

# %%
combined_zinc1
# Out:
#                             Name  nAcid   ALogP    ALogp2       AMR  \
# 0          AUTOGEN_zinc_smiles_1    NaN -0.0588  0.003457   59.2490
# 1          AUTOGEN_zinc_smiles_2    NaN  0.5471  0.299318   86.6026
# 2          AUTOGEN_zinc_smiles_3    0.0 -1.2694  1.611376   74.6158
# 3          AUTOGEN_zinc_smiles_4    NaN -1.2694  1.611376   74.6158
# 4          AUTOGEN_zinc_smiles_5    0.0  0.8833  0.780219   65.8004
# 5          AUTOGEN_zinc_smiles_6    NaN -2.4549  6.026534   75.7435
# 6          AUTOGEN_zinc_smiles_7    0.0  0.2350  0.055225   95.0888
# 7          AUTOGEN_zinc_smiles_8    0.0 -1.5289  2.337535   89.0826
# 8          AUTOGEN_zinc_smiles_9    0.0 -0.1931  0.037288   68.9788
# 9         AUTOGEN_zinc_smiles_10    0.0  0.0430  0.001849   64.0520
# 10        AUTOGEN_zinc_smiles_11    0.0 -0.1026  0.010527   87.0599
# 11        AUTOGEN_zinc_smiles_12    0.0 -0.2378  0.056549   45.7210
# 12        AUTOGEN_zinc_smiles_13    0.0 -2.1215  4.500762   74.4626
# ...

# %%
pd.value_counts(combined_zinc1.Name)
# Out:
# AUTOGEN_zinc_smiles_1000     2
# AUTOGEN_zinc_smiles_17671    2
# AUTOGEN_zinc_smiles_10154    2
# AUTOGEN_zinc_smiles_6852     2
# AUTOGEN_zinc_smiles_14404    2
# AUTOGEN_zinc_smiles_14636    2
# AUTOGEN_zinc_smiles_7404     2
# AUTOGEN_zinc_smiles_9956     2
# AUTOGEN_zinc_smiles_9581     2
# AUTOGEN_zinc_smiles_14730    2
# AUTOGEN_zinc_smiles_1580     2
# AUTOGEN_zinc_smiles_15815    2
# AUTOGEN_zinc_smiles_14721    2
# AUTOGEN_zinc_smiles_8296     2
# AUTOGEN_zinc_smiles_299      2
# AUTOGEN_zinc_smiles_9479     2
# AUTOGEN_zinc_smiles_2408     2
# AUTOGEN_zinc_smiles_8274     2
# AUTOGEN_zinc_smiles_9579     2
# AUTOGEN_zinc_smiles_14212    2
# AUTOGEN_zinc_smiles_7755     2
# AUTOGEN_zinc_smiles_1587     2
# AUTOGEN_zinc_smiles_17220    2
# AUTOGEN_zinc_smiles_2546     2
# AUTOGEN_zinc_smiles_12852    2
# AUTOGEN_zinc_smiles_16646    2
# AUTOGEN_zinc_smiles_1679     2
# AUTOGEN_zinc_smiles_8516     2
# AUTOGEN_zinc_smiles_4060     2
# AUTOGEN_zinc_smiles_10422    2
# ...

# %%
combined_zinc1_1 = combined_zinc1.reset_index().drop_duplicates(subset='index', keep='first').set_index('index')

# %%
pd.value_counts(combined_zinc1_1.Name)
combined_zinc1_1
# Out:
#                             Name  nAcid   ALogP    ALogp2       AMR  \
# index
# 0          AUTOGEN_zinc_smiles_1    NaN -0.0588  0.003457   59.2490
# 1          AUTOGEN_zinc_smiles_2    NaN  0.5471  0.299318   86.6026
# 2          AUTOGEN_zinc_smiles_3    0.0 -1.2694  1.611376   74.6158
# 3          AUTOGEN_zinc_smiles_4    NaN -1.2694  1.611376   74.6158
# 4          AUTOGEN_zinc_smiles_5    0.0  0.8833  0.780219   65.8004
# 5          AUTOGEN_zinc_smiles_6    NaN -2.4549  6.026534   75.7435
# 6          AUTOGEN_zinc_smiles_7    0.0  0.2350  0.055225   95.0888
# 7          AUTOGEN_zinc_smiles_8    0.0 -1.5289  2.337535   89.0826
# 8          AUTOGEN_zinc_smiles_9    0.0 -0.1931  0.037288   68.9788
# 9         AUTOGEN_zinc_smiles_10    0.0  0.0430  0.001849   64.0520
# 10        AUTOGEN_zinc_smiles_11    0.0 -0.1026  0.010527   87.0599
# 11        AUTOGEN_zinc_smiles_12    0.0 -0.2378  0.056549   45.7210
# 12        AUTOGEN_zinc_smiles_13    0.0 -2.1215  4.500762   74.4626
# ...

# %%
combined_zinc1.drop_duplicates(['Name'])
# Out:
#                             Name  nAcid   ALogP    ALogp2       AMR  \
# 0          AUTOGEN_zinc_smiles_1    NaN -0.0588  0.003457   59.2490
# 1          AUTOGEN_zinc_smiles_2    NaN  0.5471  0.299318   86.6026
# 2          AUTOGEN_zinc_smiles_3    0.0 -1.2694  1.611376   74.6158
# 3          AUTOGEN_zinc_smiles_4    NaN -1.2694  1.611376   74.6158
# 4          AUTOGEN_zinc_smiles_5    0.0  0.8833  0.780219   65.8004
# 5          AUTOGEN_zinc_smiles_6    NaN -2.4549  6.026534   75.7435
# 6          AUTOGEN_zinc_smiles_7    0.0  0.2350  0.055225   95.0888
# 7          AUTOGEN_zinc_smiles_8    0.0 -1.5289  2.337535   89.0826
# 8          AUTOGEN_zinc_smiles_9    0.0 -0.1931  0.037288   68.9788
# 9         AUTOGEN_zinc_smiles_10    0.0  0.0430  0.001849   64.0520
# 10        AUTOGEN_zinc_smiles_11    0.0 -0.1026  0.010527   87.0599
# 11        AUTOGEN_zinc_smiles_12    0.0 -0.2378  0.056549   45.7210
# 12        AUTOGEN_zinc_smiles_13    0.0 -2.1215  4.500762   74.4626
# ...

# %%
pd.value_counts(combined_zinc1.Name)
# Out:
# AUTOGEN_zinc_smiles_1000     2
# AUTOGEN_zinc_smiles_17671    2
# AUTOGEN_zinc_smiles_10154    2
# AUTOGEN_zinc_smiles_6852     2
# AUTOGEN_zinc_smiles_14404    2
# AUTOGEN_zinc_smiles_14636    2
# AUTOGEN_zinc_smiles_7404     2
# AUTOGEN_zinc_smiles_9956     2
# AUTOGEN_zinc_smiles_9581     2
# AUTOGEN_zinc_smiles_14730    2
# AUTOGEN_zinc_smiles_1580     2
# AUTOGEN_zinc_smiles_15815    2
# AUTOGEN_zinc_smiles_14721    2
# AUTOGEN_zinc_smiles_8296     2
# AUTOGEN_zinc_smiles_299      2
# AUTOGEN_zinc_smiles_9479     2
# AUTOGEN_zinc_smiles_2408     2
# AUTOGEN_zinc_smiles_8274     2
# AUTOGEN_zinc_smiles_9579     2
# AUTOGEN_zinc_smiles_14212    2
# AUTOGEN_zinc_smiles_7755     2
# AUTOGEN_zinc_smiles_1587     2
# AUTOGEN_zinc_smiles_17220    2
# AUTOGEN_zinc_smiles_2546     2
# AUTOGEN_zinc_smiles_12852    2
# AUTOGEN_zinc_smiles_16646    2
# AUTOGEN_zinc_smiles_1679     2
# AUTOGEN_zinc_smiles_8516     2
# AUTOGEN_zinc_smiles_4060     2
# AUTOGEN_zinc_smiles_10422    2
# ...

# %%
combined_zinc1.reset_index()
# Out:
#        index                       Name  nAcid   ALogP    ALogp2       AMR  \
# 0          0      AUTOGEN_zinc_smiles_1    NaN -0.0588  0.003457   59.2490
# 1          1      AUTOGEN_zinc_smiles_2    NaN  0.5471  0.299318   86.6026
# 2          2      AUTOGEN_zinc_smiles_3    0.0 -1.2694  1.611376   74.6158
# 3          3      AUTOGEN_zinc_smiles_4    NaN -1.2694  1.611376   74.6158
# 4          4      AUTOGEN_zinc_smiles_5    0.0  0.8833  0.780219   65.8004
# 5          5      AUTOGEN_zinc_smiles_6    NaN -2.4549  6.026534   75.7435
# 6          6      AUTOGEN_zinc_smiles_7    0.0  0.2350  0.055225   95.0888
# 7          7      AUTOGEN_zinc_smiles_8    0.0 -1.5289  2.337535   89.0826
# 8          8      AUTOGEN_zinc_smiles_9    0.0 -0.1931  0.037288   68.9788
# 9          9     AUTOGEN_zinc_smiles_10    0.0  0.0430  0.001849   64.0520
# 10        10     AUTOGEN_zinc_smiles_11    0.0 -0.1026  0.010527   87.0599
# ...

# %%
combined_zinc1.drop_duplicates(['Name'])
# Out:
#                             Name  nAcid   ALogP    ALogp2       AMR  \
# 0          AUTOGEN_zinc_smiles_1    NaN -0.0588  0.003457   59.2490
# 1          AUTOGEN_zinc_smiles_2    NaN  0.5471  0.299318   86.6026
# 2          AUTOGEN_zinc_smiles_3    0.0 -1.2694  1.611376   74.6158
# 3          AUTOGEN_zinc_smiles_4    NaN -1.2694  1.611376   74.6158
# 4          AUTOGEN_zinc_smiles_5    0.0  0.8833  0.780219   65.8004
# 5          AUTOGEN_zinc_smiles_6    NaN -2.4549  6.026534   75.7435
# 6          AUTOGEN_zinc_smiles_7    0.0  0.2350  0.055225   95.0888
# 7          AUTOGEN_zinc_smiles_8    0.0 -1.5289  2.337535   89.0826
# 8          AUTOGEN_zinc_smiles_9    0.0 -0.1931  0.037288   68.9788
# 9         AUTOGEN_zinc_smiles_10    0.0  0.0430  0.001849   64.0520
# 10        AUTOGEN_zinc_smiles_11    0.0 -0.1026  0.010527   87.0599
# 11        AUTOGEN_zinc_smiles_12    0.0 -0.2378  0.056549   45.7210
# 12        AUTOGEN_zinc_smiles_13    0.0 -2.1215  4.500762   74.4626
# ...

# %%
pd.value_counts(combined_zinc1.Name)
# Out:
# AUTOGEN_zinc_smiles_1000     2
# AUTOGEN_zinc_smiles_17671    2
# AUTOGEN_zinc_smiles_10154    2
# AUTOGEN_zinc_smiles_6852     2
# AUTOGEN_zinc_smiles_14404    2
# AUTOGEN_zinc_smiles_14636    2
# AUTOGEN_zinc_smiles_7404     2
# AUTOGEN_zinc_smiles_9956     2
# AUTOGEN_zinc_smiles_9581     2
# AUTOGEN_zinc_smiles_14730    2
# AUTOGEN_zinc_smiles_1580     2
# AUTOGEN_zinc_smiles_15815    2
# AUTOGEN_zinc_smiles_14721    2
# AUTOGEN_zinc_smiles_8296     2
# AUTOGEN_zinc_smiles_299      2
# AUTOGEN_zinc_smiles_9479     2
# AUTOGEN_zinc_smiles_2408     2
# AUTOGEN_zinc_smiles_8274     2
# AUTOGEN_zinc_smiles_9579     2
# AUTOGEN_zinc_smiles_14212    2
# AUTOGEN_zinc_smiles_7755     2
# AUTOGEN_zinc_smiles_1587     2
# AUTOGEN_zinc_smiles_17220    2
# AUTOGEN_zinc_smiles_2546     2
# AUTOGEN_zinc_smiles_12852    2
# AUTOGEN_zinc_smiles_16646    2
# AUTOGEN_zinc_smiles_1679     2
# AUTOGEN_zinc_smiles_8516     2
# AUTOGEN_zinc_smiles_4060     2
# AUTOGEN_zinc_smiles_10422    2
# ...

# %%
combined_zinc1.drop_duplicates(['Name'], keep='first', inplace=True)

# %%
pd.value_counts(combined_zinc1.Name)
# Out:
# AUTOGEN_zinc_smiles_21044    1
# AUTOGEN_zinc_smiles_7418     1
# AUTOGEN_zinc_smiles_26720    1
# AUTOGEN_zinc_smiles_16410    1
# AUTOGEN_zinc_smiles_188      1
# AUTOGEN_zinc_smiles_10643    1
# AUTOGEN_zinc_smiles_33815    1
# AUTOGEN_zinc_smiles_20105    1
# AUTOGEN_zinc_smiles_1607     1
# AUTOGEN_zinc_smiles_27127    1
# AUTOGEN_zinc_smiles_20454    1
# AUTOGEN_zinc_smiles_6594     1
# AUTOGEN_zinc_smiles_22351    1
# AUTOGEN_zinc_smiles_18163    1
# AUTOGEN_zinc_smiles_12609    1
# AUTOGEN_zinc_smiles_7477     1
# AUTOGEN_zinc_smiles_21058    1
# AUTOGEN_zinc_smiles_6909     1
# AUTOGEN_zinc_smiles_10589    1
# AUTOGEN_zinc_smiles_7480     1
# AUTOGEN_zinc_smiles_6303     1
# AUTOGEN_zinc_smiles_23825    1
# AUTOGEN_zinc_smiles_18359    1
# AUTOGEN_zinc_smiles_5259     1
# AUTOGEN_zinc_smiles_25461    1
# AUTOGEN_zinc_smiles_26182    1
# AUTOGEN_zinc_smiles_31376    1
# AUTOGEN_zinc_smiles_7908     1
# AUTOGEN_zinc_smiles_4398     1
# AUTOGEN_zinc_smiles_9238     1
# ...

# %%
combined_zinc1.to_csv('combined_zinc1.csv')

# %%
combined_zinc2 = pd.read_csv('../../big datasets/csv/combined_zinc2.csv')

# %%
combined_zinc2.shape
# Out:
# (40226, 1445)

# %%
combined_zinc2.drop_duplicates(['Name'], keep='first', inplace=True)
combined_zinc2.to_csv('combined_zinc2-1.csv')

# %%
combined_zinc2 = combined_zinc2.iloc[:40001,:]

# %%
combined_zinc2.tail()
# Out:
#                              Name  nAcid   ALogP    ALogp2       AMR  \
# 40221   AUTOGEN_zinc_smiles2_9996      0  0.8407  0.706776   91.3592
# 40222   AUTOGEN_zinc_smiles2_9997      0  1.6683  2.783225  100.6638
# 40223   AUTOGEN_zinc_smiles2_9998      0 -0.4161  0.173139   85.0681
# 40224   AUTOGEN_zinc_smiles2_9999      0 -1.0027  1.005407   88.6334
# 40225  AUTOGEN_zinc_smiles2_10000      0 -1.0373  1.075991   68.4791
#
#             apol  naAromAtom  nAromBond  nAtom  nHeavyAtom  ...        AMW  \
# 40221  42.393723           0          0     33          22  ...   9.517084
# 40222  45.529930           0          0     33          23  ...  11.030159
# 40223  40.171516           0          0     33          21  ...   8.608136
# 40224  42.733516           0          0     35          23  ...   8.916097
# 40225  38.637895           0          0     36          21  ...   8.363327
#
#           WTPT-1    WTPT-2     WTPT-3     WTPT-4     WTPT-5   WPATH  WPOL  \
# ...

# %%
combined_zinc2.drop_duplicates(['Name'], keep='first', inplace=True)
pd.value_counts(combined_zinc2.Name)
# Out:
# AUTOGEN_zinc_smiles2_3581     1
# AUTOGEN_zinc_smiles2_1371     1
# AUTOGEN_zinc_smiles2_12855    1
# AUTOGEN_zinc_smiles2_24235    1
# AUTOGEN_zinc_smiles2_7914     1
# AUTOGEN_zinc_smiles2_33595    1
# AUTOGEN_zinc_smiles2_24392    1
# AUTOGEN_zinc_smiles2_31757    1
# AUTOGEN_zinc_smiles2_11967    1
# AUTOGEN_zinc_smiles2_224      1
# AUTOGEN_zinc_smiles2_4186     1
# AUTOGEN_zinc_smiles2_25995    1
# AUTOGEN_zinc_smiles2_30330    1
# AUTOGEN_zinc_smiles2_18042    1
# AUTOGEN_zinc_smiles2_9248     1
# AUTOGEN_zinc_smiles2_35616    1
# AUTOGEN_zinc_smiles2_29805    1
# AUTOGEN_zinc_smiles2_19536    1
# AUTOGEN_zinc_smiles2_25699    1
# AUTOGEN_zinc_smiles2_37710    1
# AUTOGEN_zinc_smiles2_3591     1
# AUTOGEN_zinc_smiles2_22584    1
# AUTOGEN_zinc_smiles2_8267     1
# AUTOGEN_zinc_smiles2_7183     1
# AUTOGEN_zinc_smiles2_1961     1
# AUTOGEN_zinc_smiles2_35196    1
# AUTOGEN_zinc_smiles2_10540    1
# AUTOGEN_zinc_smiles2_32814    1
# AUTOGEN_zinc_smiles2_27373    1
# ...

# %%
combined_zinc2.shape
# Out:
# (40001, 1445)

# %%
 combined_zinc2.sort_values(by=['Name'])
# Out:
#                              Name  nAcid   ALogP    ALogp2       AMR  \
# 0          AUTOGEN_zinc_smiles2_1      0 -0.6289  0.395515  123.5691
# 9         AUTOGEN_zinc_smiles2_10      0  1.2307  1.514622  121.6204
# 99       AUTOGEN_zinc_smiles2_100      0 -1.2432  1.545546   96.1926
# 14999   AUTOGEN_zinc_smiles2_1000      0 -0.5336  0.284729  104.7682
# 999    AUTOGEN_zinc_smiles2_10001      0 -1.2912  1.667197  122.0261
# 1000   AUTOGEN_zinc_smiles2_10002      0 -1.8262  3.335006   62.8510
# 1001   AUTOGEN_zinc_smiles2_10003      0 -1.1766  1.384388   84.1862
# 1002   AUTOGEN_zinc_smiles2_10004      0 -1.1766  1.384388   84.1862
# 1003   AUTOGEN_zinc_smiles2_10005      0 -2.9422  8.656541   73.8189
# 1004   AUTOGEN_zinc_smiles2_10006      0 -1.3412  1.798817   94.4875
# 1005   AUTOGEN_zinc_smiles2_10007      0 -1.0373  1.075991   68.4791
# 1006   AUTOGEN_zinc_smiles2_10008      0 -1.1766  1.384388   84.1862
# 1007   AUTOGEN_zinc_smiles2_10009      0 -0.6659  0.443423   78.2237
# ...

# %%
combined_zinc2.set_index(['Name'])
# Out:
#                            nAcid   ALogP     ALogp2       AMR       apol  \
# Name
# AUTOGEN_zinc_smiles2_1         0 -0.6289   0.395515  123.5691  78.428927
# AUTOGEN_zinc_smiles2_2         0 -0.6289   0.395515  123.5691  78.428927
# AUTOGEN_zinc_smiles2_3         0 -0.6289   0.395515  123.5691  78.428927
# AUTOGEN_zinc_smiles2_4         0 -1.9395   3.761660  109.8232  59.173032
# AUTOGEN_zinc_smiles2_5         0 -1.0299   1.060694   87.6818  59.083411
# AUTOGEN_zinc_smiles2_6         0 -1.0299   1.060694   87.6818  59.083411
# AUTOGEN_zinc_smiles2_7         0 -1.0299   1.060694   87.6818  59.083411
# AUTOGEN_zinc_smiles2_8         0 -1.0299   1.060694   87.6818  59.083411
# AUTOGEN_zinc_smiles2_9         0 -0.5981   0.357724   94.1316  52.489446
# AUTOGEN_zinc_smiles2_10        0  1.2307   1.514622  121.6204  60.526653
# AUTOGEN_zinc_smiles2_11        0  1.2307   1.514622  121.6204  60.526653
# AUTOGEN_zinc_smiles2_12        0  0.1937   0.037520   68.2816  44.809032
# ...

# %%
zinc2 = list(combined_zinc2.index.values)

# %%
len(zinc2)
# Out:
# 40001

# %%
unique_z2 = combined_zinc2.index.unique()

# %%
len(unique_z2)
# Out:
# 40001

# %%
zinc2

# %%
#this is correct for the numbering of the molecules inside the files
combined_zinc3 = pd.read_csv('../../big datasets/csv/combined_zinc4.csv')
combined_zinc3.drop_duplicates(['Name'], keep='first', inplace=True)
combined_zinc3.to_csv('combined_zinc3-1.csv')

# %%
#this is correct for the numbering of the molecules inside the files
combined_zinc4 = pd.read_csv('../../big datasets/csv/combined_zinc3.csv')
combined_zinc4.drop_duplicates(['Name'], keep='first', inplace=True)
combined_zinc4.to_csv('combined_zinc4-1.csv')

# %%
zinc4 = pd.read_csv(r'../../big datasets/csv/concat csv/combined_zinc4-1.csv', low_memory=False)

# %%
from natsort import natsorted, index_natsorted, order_by_index

# %%
zinc4.set_index(['Name'])
# Out:
#                            Unnamed: 0  nAcid   ALogP     ALogp2       AMR  \
# Name
# AUTOGEN_zinc_smiles3_1              0      0 -1.8756   3.517875  106.7568
# AUTOGEN_zinc_smiles3_2              1      0 -3.2468  10.541710   88.7711
# AUTOGEN_zinc_smiles3_3              2      0 -1.2410   1.540081  124.8260
# AUTOGEN_zinc_smiles3_4              3      0 -2.3925   5.724056  113.3579
# AUTOGEN_zinc_smiles3_5              4      0 -1.4370   2.064969   96.0201
# AUTOGEN_zinc_smiles3_6              5      0 -1.3390   1.792921  110.9110
# AUTOGEN_zinc_smiles3_7              6      0 -2.0144   4.057807  120.2481
# AUTOGEN_zinc_smiles3_8              7      0 -1.4022   1.966165  100.5693
# AUTOGEN_zinc_smiles3_9              8      0 -0.4248   0.180455  124.5357
# AUTOGEN_zinc_smiles3_10             9      0 -1.9463   3.788084  111.6075
# AUTOGEN_zinc_smiles3_11            10      0 -2.9986   8.991602   93.4705
# AUTOGEN_zinc_smiles3_12            11      0 -3.4702  12.042288  103.0595
# ...

# %%
zinc4 = zinc4.reindex(index=order_by_index(zinc4.index, index_natsorted(zinc4.Name)))

# %%
zinc3.tail(100)
# Out:
#       Unnamed: 0                       Name  nAcid   ALogP     ALogp2  \
# 1904        1904  AUTOGEN_zinc_smiles4_4901      0 -0.1493   0.022290
# 1905        1905  AUTOGEN_zinc_smiles4_4902      0  0.5500   0.302500
# 1906        1906  AUTOGEN_zinc_smiles4_4903      0  1.0486   1.099562
# 1907        1907  AUTOGEN_zinc_smiles4_4904      0  0.2073   0.042973
# 1908        1908  AUTOGEN_zinc_smiles4_4905      0  0.9584   0.918531
# 1909        1909  AUTOGEN_zinc_smiles4_4906      0  0.5500   0.302500
# 1910        1910  AUTOGEN_zinc_smiles4_4907      0 -0.4128   0.170404
# 1911        1911  AUTOGEN_zinc_smiles4_4908      0  1.0834   1.173756
# 1912        1912  AUTOGEN_zinc_smiles4_4909      0  1.3970   1.951609
# 1913        1913  AUTOGEN_zinc_smiles4_4910      0  1.4318   2.050051
# 1914        1914  AUTOGEN_zinc_smiles4_4911      0  0.8877   0.788011
# 1915        1915  AUTOGEN_zinc_smiles4_4912      0  0.1887   0.035608
# ...

# %%
zinca=zinc2.iloc[:40000,:]
zinca.tail()
# Out:
#        Unnamed: 0                        Name  nAcid   ALogP    ALogp2  \
# 31994     31994.0  AUTOGEN_zinc_smiles2_39996    0.0 -2.0741  4.301891
# 31995     31995.0  AUTOGEN_zinc_smiles2_39997    0.0 -1.4757  2.177690
# 31996     31996.0  AUTOGEN_zinc_smiles2_39998    0.0 -1.4757  2.177690
# 31997     31997.0  AUTOGEN_zinc_smiles2_39999    0.0 -0.6290  0.395641
# 31998     31998.0  AUTOGEN_zinc_smiles2_40000    0.0 -1.1896  1.415148
#
#             AMR       apol  naAromAtom  nAromBond  nAtom  ...       AMW  \
# 31994  129.7310  78.750169         0.0        0.0   68.0  ...  6.930179
# 31995  125.8419  68.166239         0.0        0.0   57.0  ...  8.458521
# 31996  125.8419  68.166239         0.0        0.0   57.0  ...  8.458521
# 31997  141.3346  71.926239         0.0        0.0   59.0  ...  8.155318
# 31998  124.2296  68.937825         0.0        0.0   58.0  ...  7.641112
#
#           WTPT-1    WTPT-2     WTPT-3     WTPT-4     WTPT-5   WPATH  WPOL  \
# ...

# %%
zinc4.to_csv('../../big datasets/csv/concat csv/combined_zinc4-1.csv')

# %%
os.chdir(r'C:\Users\ellie\Desktop\Dave Beck\big datasets\csv\concat csv')

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

zinc_descriptors = pd.concat([pd.read_csv(f) for f in all_filenames ])
zinc_descriptors.to_csv('zinc_descriptors.csv', index=False)
#export to csv
#combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
